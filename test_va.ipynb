# %%
# %load_ext autoreload
# %autoreload 2

import numpy  as np
import pandas as pd
import h5py

from astropy    import units
from matplotlib import pyplot as plt

from scipy.interpolate import RegularGridInterpolator
from scipy.signal      import argrelextrema

from common import hallmark as hm
from common import mockservation as mk
from common import dalt
from common import viz

import rapplot

# %% [markdown]
# ## Load simulation data from cache

# %%
pf = hm.ParaFrame('output/plot/{mag}a{aspin:g}_w{window:d}_{}/Rh{Rhigh:d}_i{inc:d}/img_data_{snapshot:d}.h5')

for k in set(pf.keys()) - {'path'}:
    globals()[k] = np.unique(pf[k])
    print(k, globals()[k][:16])
# Out:
# window [1]
# Rhigh [1]
# inc [60]
# snapshot [1]
# mag ['M']
# aspin [101.]

# %%
def load(f):
    with h5py.File(f) as h:
        m    = h['meta']
        meta = dalt.ImageMeta(**{k:m[k][()] for k in m.keys()})
        data = h['data'][:]
    return dalt.Image(data, meta=meta)
        
mov = load(pf().path.iloc[64])
viz.show(mov, s=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       5         data = h['data'][:]
#       6     return dalt.Image(data, meta=meta)
# ----> 8 imgs = io.load_mov(sel.path)
#
# NameError: name 'io' is not defined

# %%
vis = mk.mockserve(array, N=128)
viz.show(vis, s=0, f=lambda v: np.log(abs(v).value))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 vis = mk.mockserve(array, N=128)
#       2 viz.show(vis, s=0, f=lambda v: np.log(abs(v).value))
#
# File ~/Documents/UR/NkS/2017_sgra_paper5/common/mockservation.py:166, in mockserve(imgs, N)
#     165 def mockserve(imgs, N=None):
# --> 166     px = imgs.fov / imgs.shape[-2:]
#     167     pa = abs(px[0] * px[1])
#     168     m  = imgs.meta
#
# AttributeError: 'numpy.ndarray' object has no attribute 'fov'

# %%
U, V = vis.uvd

u = np.linspace( 0,   U/2, num=vis.shape[-1])
v = np.linspace(-V/2, V/2, num=vis.shape[-2], endpoint=False)
t = vis.meta.time.value

amp = RegularGridInterpolator((t, v, u[::-1]), abs     (vis[...,::-1]))
phi = RegularGridInterpolator((t, v, u[::-1]), np.angle(vis[...,::-1]))

# %%
bmin = 6e9
bmax = 8e9

uvd = np.linspace(0, bmax, round(bmax/2e8)+1)

for i in range(-90,90+1,20):
    phi = np.pi * i / 180

    u = uvd * np.cos(phi)
    v = uvd * np.sin(phi)

    mask = u <= 0
    
    p = np.array([np.repeat(t[0], np.sum( mask)),  v[ mask],  u[ mask]]).T
    m = np.array([np.repeat(t[0], np.sum(~mask)), -v[~mask], -u[~mask]]).T
    
    s = np.zeros(len(uvd))
    s[ mask] = amp(p)
    s[~mask] = amp(m)
        
    plt.semilogy(uvd, s/s[0], ':' if i < 0 else '-', label=f'i={i}')

    lm = argrelextrema(s, np.less)[0]
    plt.scatter(uvd[lm], s[lm]/s[0])
    
    ms = np.median(s[(bmin < uvd) & (uvd < bmax)]) / s[0]
    plt.plot([bmin, bmax], [ms, ms], ':' if i < 0 else '-', alpha=1/3)

plt.legend()
